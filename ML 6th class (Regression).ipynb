# %%
# Regression

# %%
# supervised lerning 
# 1. classification
# 2. regression

# %%
# unsupervised lerning
# 1.clustering
# 2.association
# 3.dimenstion reduction

# %%
# Regression

# %%
# regression means yuor output will be in numerical data

# %%
# Two type of regression

# %%
# 1.Linear regression
# 2.logistic regression

# %%
# in linear regression you are predicating numerical value giving the data in model

# %%
# in logistic regression is predict the catoogries data

# %% [markdown]
# # Linear regression

# %%
# linear equation formula
# y=mx+c
# y is output
# x is input
# m is slope 
# m=(y2-y1)/(x2-x1)

# %%
# c= (sumation of y -m summation x)/n

# %%
# c is intercept

# %%
import matplotlib.pyplot as plt

screen_time = [1, 2, 3]
marks = [75, 70, 55]

plt.plot(screen_time, marks)

plt.xlabel("Student Screen Time")
plt.ylabel("Marks")
plt.title("Screen Time vs Marks")

plt.show()

# %%
# cost function is change value of slope and intercept

# %%
# formula is : 1/n summation(yi-ycap) ka whole squre
# this is also called as mean squre error

# %%
# yi is actual value 
# y cap is predictated value
# # n= no.of values

# %% [markdown]
# # Gradient decent function

# %% [markdown]
# to reduce the cost function or say reduce the error this gradient decent function

# %%
# there is formula is :

# %%
# new(m,c)=old(m,c)-n(delj/del(m,c))
# now n is ita not n
# ita is a lerning rate

# %%
# it is also called as increase and decrese the slope and intercept value

# %%
# grdient decent function is show direction increase/decrese(m,c)
